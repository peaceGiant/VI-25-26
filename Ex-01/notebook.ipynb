# %%
x = 2

# %%
x = 2
print(x)
x = 'two'
x
# Out:
# 2
# 'two'

# %%
x = 2

# %%
x -= 2
x
# Out:
# 0

# %%
x = 2
not ((x > 0) or (x < 10))
# Out:
# False

# %%
2 ^ 1
# Out:
# 3

# %%
5 in [1, 2, 3]
# Out:
# True

# %%
x = [1, 2, 3]
y = x
x is y
# Out:
# True

# %%
x = 10000
y = x
x.append(4)
print(x, y)
# Out:
# [1, 2, 3, 4] [1, 2, 3]

# %%
pts = 71
grade = 5
if pts < 50:
    grade = 5
else:
    print('studentot polozhil')


grade
# Out:
# studentot polozhil
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 8
#       4 else:
#       5     print('studentot polozhil')
# ----> 8 grade
#
# NameError: name 'grade' is not defined

# %%
x = (1, 2, 3,)

# %%
x = 'hello world'

# %%
x = 'goodbye world!'

# %%
x = 'lets take a break'

# %%
x
# Out:
# 'lets take a break'

# %%
x = 2

# %%
l = [1, 2, 3]

# %%
l[-1]
# Out:
# 3

# %%
x = tuple([1, 2, 3, 4])

# %%
x[0]
# Out:
# 1

# %%
d = {'key1': 20, 'key2': 30, 10: [1, 2, 3]}

# %%
d.pop('key1')
# Out:
# 20

# %%
d = {}
# Out:
# {10: [1, 2, 3]}

# %%
def f(x, y, z):
    a = x + y
    b = z ** x
    return a, b

# %%
# 1.
f(10, 3, 20)
# 2.
f(x=10, y=20, z=30)
# Out:
# (30, 590490000000000)

# %%
f = lambda x, y, z: (x + y, z ** x)

# %%
f(1, 2, 3)
# Out:
# (3, 3)

# %%
fs = {1}
for i in range(3):
    f = lambda x: x + i
    fs.add(f)

fs
# Out:
# {1,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>}

# %%
pts = 71
has_passed = False if pts < 50 else True

# %%
has_passed
# Out:
# True

# %%
l = [1, 2, 3]

# %%
l_new = [el * 2 for el in l if el * 2 < 5]

# %%
# Out:
# True

# %%
g = iter(range(10))

# %%
next(g)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 next(g)
#
# StopIteration:
